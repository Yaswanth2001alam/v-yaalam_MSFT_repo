# %%
success = 1

if success == True:
    celebrate()
while success == False:
    tryAgain()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 success = 1
#       3 if success == True:
# ----> 4     celebrate()
#       5 while success == False:
#       6     tryAgain()
#
# NameError: name 'celebrate' is not defined

# %%
success = False

while not success:
    success = tryAgain()

celebrate()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 success = False
#       3 while not success:
# ----> 4     success = tryAgain()
#       6 celebrate()
#
# NameError: name 'tryAgain' is not defined

# %%
def tryAgain():
    print("Trying again...")
    return True   # simulate success

def celebrate():
    print("🎉 Success! Celebrating! 1234..,,,,")

success = False

while not success:
    success = tryAgain()

celebrate()
# Out:
# Trying again...
# 🎉 Success! Celebrating! 1234..,,,,

# %%
print("hello")
