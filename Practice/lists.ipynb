# %%
friends = ["paul", "Dana", "Nathan", "Lilly"]
friends[1:]
# Out:
# ['Dana', 'Nathan', 'Lilly']

# %%
friends = ["paul", "Dana", "Nathan", "Lilly"]
friends[:-1]
# Out:
# ['paul', 'Dana', 'Nathan']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
friends [2 : 3]
# Out:
# ['Nathan']

# %%
friends[3:]
# Out:
# ['Lilly']

# %%
friends[4:]
# Out:
# []

# %%
friends[-1:]
# Out:
# ['Lilly']

# %%
friends[:-3]
# Out:
# ['paul']

# %%
friends.append("Yaswanth")
friends
# Out:
# ['paul', 'Dana', 'Nathan', 'Lilly', 'Yaswanth', 'Yaswanth']

# %%
friends.append("Alam")

# %%
friends
# Out:
# ['paul', 'Dana', 'Nathan', 'Lilly', 'Yaswanth', 'Yaswanth', 'Alam']

# %%
friends.append("example")
friends
# Out:
# ['paul', 'Dana', 'Nathan', 'Lilly', 'Yaswanth', 'Yaswanth', 'Alam', 'example']

# %%
friends
friends.remove("Yaswanth")
friends
# Out:
# ['paul', 'Dana', 'Nathan', 'Lilly', 'Yaswanth', 'Alam', 'example']

# %%
friends.sort()
friends
# Out:
# ['Alam', 'Dana', 'Lilly', 'Nathan', 'Yaswanth', 'example', 'paul']

# %%
friends
# Out:
# ['Alam', 'Dana', 'Lilly', 'Nathan', 'Yaswanth', 'example', 'paul']

# %%
friends.copy()
# Out:
# ['Alam', 'Dana', 'Lilly', 'Nathan', 'Yaswanth', 'example', 'paul']

# %%
friends.insert(2 , 3434)
friends
# Out:
# ['Alam', 'Dana', 3434, 3434, 'Lilly', 'Nathan', 'Yaswanth', 'example', 'paul']

# %%
friends
# Out:
# ['Alam', 'Dana', 3434, 3434, 'Lilly', 'Nathan', 'Yaswanth', 'example', 'paul']

# %%
friends.index(3434)
# Out:
# 2

# %%
friends.index('Yaswanth')
# Out:
# 6

# %%
friends.count(3434)
# Out:
# 2

# %% [markdown]
# https://colab.research.google.com/drive/1mrY8Msx87HS4ItsUhun7IRxsn4D6OTH0?usp=sharing#scrollTo=0nTbeNwUA94L

# %% [markdown]
# Resources & Further Learning
# Practice exercises: https://go.visuallyexplained.co/lists...
# List method documentation: https://www.w3schools.com/python/pyth...
#
# 🔵 Gear We Use (Affiliate Links)
# Background hexagon lights (Amazon) → https://go.visuallyexplained.co/0ug
# Tea jars (Amazon) → https://go.visuallyexplained.co/zx7
# Python basics book (Amazon) → https://go.visuallyexplained.co/f757ff

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
movie = ['Forrest Gump', 'Good Will Hunting', 'The Big Short']

movie
# Out:
# ['Forrest Gump', 'Good Will Hunting', 'The Big Short']

# %%
movie[::2]
# Out:
# ['Forrest Gump', 'The Big Short']

# %%
movie
# Out:
# ['Forrest Gump', 'New Movie Name', 'The Big Short']

# %%
movie.insert(1 , "openheimer")

movie
# Out:
# ['Forrest Gump', 'openheimer', 'Good Will Hunting', 'The Big Short']

# %%
movie = ['Forrest Gump', 'Good Will Hunting', 'The Big Short']

# Replace 'Good Will Hunting' with a new movie name
movie[1] = 'New Movie Name'

print(movie)
# Out:
# ['Forrest Gump', 'New Movie Name', 'The Big Short']

# %%
movie
# Out:
# ['Forrest Gump', 'New Movie Name', 'The Big Short']

# %%
movie[1] = "openheimer"

# %%
movie
# Out:
# ['Forrest Gump', 'openheimer', 'The Big Short']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
guest = ["Farah", "Alex" , "Charlie", "Dana", "Brooke", "Eli"]

guest.sort()

guest
# Out:
# ['Alex', 'Brooke', 'Charlie', 'Dana', 'Eli', 'Farah']

# %%
print(guest[2:5])
# Out:
# ['Charlie', 'Dana', 'Eli']

# %%
guest
# Out:
# ['Alex', 'Brooke', 'Charlie', 'Dana', 'Eli', 'Farah']

# %%
print(guest.append("Gina"))
# Out:
# None

# %%
guest
# Out:
# ['Alex', 'Brooke', 'Charlie', 'Dana', 'Eli', 'Farah', 'Gina']

# %%
guest.append("Gina")
guest
# Out:
# ['Alex', 'Brooke', 'Charlie', 'Dana', 'Eli', 'Farah', 'Gina', 'Gina']

# %%
guest.remove("Gina")

# %%
guest
# Out:
# ['Alex', 'Brooke', 'Charlie', 'Dana', 'Eli', 'Farah', 'Gina']

# %%
guest
# Out:
# ['Brooke', 'Charlie', 'Dana', 'Eli', 'Farah', 'Gina']

# %%
guest.remove("Alex")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 guest.remove("Alex")
#
# ValueError: list.remove(x): x not in list
