# %%
arr = [1,2,3,4]

arr3 = arr.copy()

arr3.append(5)

print(arr3)
# Out:
# [1, 2, 3, 4, 5]

# %%
test = [1, 2, 45, 78, 69, 90, 100]

sql = test.copy()

sql.append("yaswnath")

print(sql)
# Out:
# [1, 2, 45, 78, 69, 90, 100, 'yaswnath']
