# %%
arr = [1,2,3,4]

arr3 = arr.copy()

arr3.append(5)

print(arr3)
# Out:
# [1, 2, 3, 4, 5]

# %%
test = [1, 2, 45, 78, 69, 90, 100]

sql = test.copy()

sql.append("yaswnath")

print(sql)
# Out:
# [1, 2, 45, 78, 69, 90, 100, 'yaswnath']

# %%
x = int(1.5)
print(x)
# Out:
# 1

# %%
x = int(1.9)
print(x)
# Out:
# 1

# %%
x = int(2.5)
print(x)
# Out:
# 2

# %%
y = float(5465)
y
# Out:
# 5465.0

# %%
z = float("4.51521")
z
# Out:
# 4.51521

# %%
print(10>9)
# Out:
# True

# %%
print(10==9)
# Out:
# False

# %%
print(10==10)
# Out:
# True

# %%
print(10<9)
# Out:
# False

# %%
print(bool("yaswanth"))
# Out:
# True

# %%
print(bool(515151541654561515))
# Out:
# True

# %%
print(bool(false))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 print(bool(false))
#
# NameError: name 'false' is not defined

# %%
print(bool(False))
# Out:
# False

# %%
print(bool(True))
# Out:
# True

# %%
class yaswanth():
    def __len__(self)
