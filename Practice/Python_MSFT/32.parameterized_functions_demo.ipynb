# %% [markdown]
# https://learn.microsoft.com/en-us/shows/intro-to-python-development/python-for-beginners-32-of-44-demo-parameterized-functions
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# D![image.png](attachment:image.png)

# %%
def get_initial(name):
    initial = name[0:5].upper()
    return initial

first_name = input("Enter the first name:  ")
first_name_initial = get_initial(first_name)

print("Your initail is: " , first_name_initial)
# Out:
# Your initail is:  YASWA

# %%
def get_initial(name , force_uppercase):
    if force_uppercase:
        initial = name[0:5].upper()
    else:
        initial = name[0:5]
    return initial

first_name = input("Enter the first name:  ")
first_name_initial = get_initial(first_name)

print("Your initail is: " , first_name_initial)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 9
#       6     return initial
#       8 first_name = input("Enter the first name:  ")
# ----> 9 first_name_initial = get_initial(first_name)
#      11 print("Your initail is: " , first_name_initial)
#
# TypeError: get_initial() missing 1 required positional argument: 'force_uppercase'

# %%
def get_initial(name , force_uppercase):
    if force_uppercase:
        initial = name[0:5].upper()
    else:
        initial = name[0:5]
    return initial

first_name = input("Enter the first name:  ")
first_name_initial = get_initial(first_name , False)

print("Your initail is: " , first_name_initial)
# Out:
# Your initail is:  Yaswa

# %%
def get_initial(name , force_uppercase=False):
    if force_uppercase:
        initial = name[0:5].upper()
    else:
        initial = name[0:5]
    return initial

first_name = input("Enter the first name:  ")
first_name_initial = get_initial(first_name)

print("Your initail is: " , first_name_initial)
# Out:
# Your initail is:  Yaswa

# %%
def get_initial(name , force_uppercase=True):
    if force_uppercase:
        initial = name[0:5].upper()
    else:
        initial = name[0:5]
    return initial

first_name = input("Enter the first name:  ")
first_name_initial = get_initial(first_name, False)

print("Your initail is: " + first_name_initial)
# Out:
# Your initail is: Yaswa

# %%
def get_initial(name , force_uppercase=True):
    if force_uppercase:
        initial = name[0:5].upper()
    else:
        initial = name[0:5]
    return initial

first_name = input("Enter the first name:  ")
first_name_initial = get_initial(first_name)

print("Your initail is: " + first_name_initial)
# Out:
# Your initail is: YASWA

# %%
def get_initial(name , force_uppercase=True):
    if force_uppercase:
        initial = name[0:5].upper()
    else:
        initial = name[0:5]
    return initial

first_name = input("Enter the first name:  ")
first_name_initial = get_initial(force_uppercase=False, name=first_name)

print("Your initail is: " + first_name_initial)
# Out:
# Your initail is: Yaswa

# %%
def get_initial(name , force_uppercase=True):
    if force_uppercase:
        initial = name[0:5].upper()
    else:
        initial = name[0:5]
    return initial

first_name = input("Enter the first name:  ")
first_name_initial = get_initial(force_uppercase=True, name=first_name)

print("Your initail is: " + first_name_initial)
# Out:
# Your initail is: YASWA
